# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df =pd.read_csv('https://raw.githubusercontent.com/italia/covid19-opendata-vaccini/master/dati/punti-somministrazione-latest.csv')
df
# Out:
#     area provincia  ... codice_regione_ISTAT nome_area
# 0    ABR    CHIETI  ...                   13   Abruzzo
# 1    ABR    CHIETI  ...                   13   Abruzzo
# 2    ABR    CHIETI  ...                   13   Abruzzo
# 3    ABR  L'AQUILA  ...                   13   Abruzzo
# 4    ABR  L'AQUILA  ...                   13   Abruzzo
# ..   ...       ...  ...                  ...       ...
# 288  VEN    ROVIGO  ...                    5    Veneto
# 289  VEN   TREVISO  ...                    5    Veneto
# 290  VEN   VENEZIA  ...                    5    Veneto
# 291  VEN    VERONA  ...                    5    Veneto
# 292  VEN   VICENZA  ...                    5    Veneto
#
# [293 rows x 8 columns]

# %% [markdown]
# 1. Eliminare tutte le colonne ad eccezione della provincia, del comune, del presidio ospedaliero e del
# nome_area

# %%
df.drop(columns=['area', 'codice_NUTS1', 'codice_NUTS2', 'codice_regione_ISTAT'], inplace=True)
df
# Out:
#     provincia  ... nome_area
# 0      CHIETI  ...   Abruzzo
# 1      CHIETI  ...   Abruzzo
# 2      CHIETI  ...   Abruzzo
# 3    L'AQUILA  ...   Abruzzo
# 4    L'AQUILA  ...   Abruzzo
# ..        ...  ...       ...
# 288    ROVIGO  ...    Veneto
# 289   TREVISO  ...    Veneto
# 290   VENEZIA  ...    Veneto
# 291    VERONA  ...    Veneto
# 292   VICENZA  ...    Veneto
#
# [293 rows x 4 columns]

# %% [markdown]
# 2. Eliminare i dati nulli

# %%
df.dropna(inplace=True)
df
# Out:
#     provincia  ... nome_area
# 0      CHIETI  ...   Abruzzo
# 1      CHIETI  ...   Abruzzo
# 2      CHIETI  ...   Abruzzo
# 3    L'AQUILA  ...   Abruzzo
# 4    L'AQUILA  ...   Abruzzo
# ..        ...  ...       ...
# 288    ROVIGO  ...    Veneto
# 289   TREVISO  ...    Veneto
# 290   VENEZIA  ...    Veneto
# 291    VERONA  ...    Veneto
# 292   VICENZA  ...    Veneto
#
# [290 rows x 4 columns]

# %% [markdown]
# 3. Visualizzare i punti vaccinali di un comune inserito dall’utente. Controllare il dato inserito: se il comune
# non esiste dare un opportuno messaggio, altrimenti visualizzare i nomi dei punti vaccinali

# %%
comune = input('inserire comune')

if comune in df['comune'].tolist():
  print(df.loc[df["comune"]==comune,"presidio_ospedaliero"])
else:
  print('comune non presente')
# Out:
# inserire comuneCHIETI
# 0    PRESIDIO OSPEDALIERO SS ANNUNZIATA
# Name: presidio_ospedaliero, dtype: object

# %% [markdown]
# 4. Visualizzare il numero di punti vaccinali di ogni regione. Visualizzare il nome della regione e il numero di
# punti vaccinali. Ordinare in ordine decrescente sul numero di punti vaccinali (dalla regione che ha più
# punti vaccinali a quella che ne ha di meno)

# %%
df1 = df.groupby('nome_area')['presidio_ospedaliero'].count().sort_values(ascending=False)
df1
# Out:
# nome_area
# Lombardia                             65
# Sicilia                               33
# Piemonte                              28
# Campania                              27
# Lazio                                 20
# Liguria                               14
# Emilia-Romagna                        13
# Toscana                               12
# Sardegna                              12
# Puglia                                11
# Veneto                                 7
# Abruzzo                                7
# Marche                                 7
# Provincia Autonoma Bolzano / Bozen     7
# Calabria                               6
# Friuli-Venezia Giulia                  5
# Basilicata                             5
# Umbria                                 4
# Provincia Autonoma Trento              3
# Valle d'Aosta / Vallée d'Aoste         2
# Molise                                 2
# Name: presidio_ospedaliero, dtype: int64

# %% [markdown]
# 5. Visualizzare il grafico a barre orizzontali relativo all’esercizio 4. Inserire il titolo, i nomi degli assi e la
# legenda. Fare in modo che i colori delle barre siano gradazioni dello stesso colore.

# %%
import seaborn as sns
fig = plt.figure()
ax = plt.axes()
sns.barplot(x=df1.values, y=df1.index, palette='Blues_d', label='Presidi Ospedalieri per ogni Regione')
fig.suptitle('Presidi Ospedalieri per ogni Regione')
ax.set_xlabel('Numero Presidi Ospedalieri')
ax.set_ylabel('Regioni')
ax.legend()
plt.show()

# %% [markdown]
# 6. Visualizzare il numero di province per ogni regione

# %%
df2 = df.pivot_table(columns=['nome_area', 'provincia'], aggfunc='size').reset_index()
dfpro =df2.groupby('nome_area')['provincia'].count().reset_index()
dfpro
# Out:
#                              nome_area  provincia
# 0                              Abruzzo          4
# 1                           Basilicata          2
# 2                             Calabria          5
# 3                             Campania          5
# 4                       Emilia-Romagna          9
# 5                Friuli-Venezia Giulia          4
# 6                                Lazio          6
# 7                              Liguria          5
# 8                            Lombardia         12
# 9                               Marche          5
# 10                              Molise          1
# 11                            Piemonte          8
# 12  Provincia Autonoma Bolzano / Bozen          1
# 13           Provincia Autonoma Trento          1
# 14                              Puglia          6
# 15                            Sardegna          8
# 16                             Sicilia          9
# 17                             Toscana         10
# 18                              Umbria          2
# 19      Valle d'Aosta / Vallée d'Aoste          1
# 20                              Veneto          7

# %% [markdown]
# 7. Visualizzare il grafico a torta dei dati dell’esercizio precedente. Inserire il titolo e la legenda

# %%
fig = plt.figure()
ax = plt.axes()
ax.pie(dfpro['provincia'], labels=dfpro['nome_area'], autopct='%1.0f%%')
fig.suptitle('Presidi Ospedalieri per Regioni')
ax.legend(dfpro['nome_area'])
plt.show()

# %% [markdown]
# 8. Visualizzare un nuovo grafico con i grafici precedenti. Il nuovo grafico deve avere due righe e tre
# colonne e deve contenere nella prima riga tre volte il grafico a barre e nella seconda riga tre volte il
# grafico a torta

# %%
fig, ((ax1,ax2,ax3),(ax4,ax5,ax6)) = plt.subplots(2,3)
ax1.barh(df1.index, df1.values, label='Presidi Ospedalieri per Regioni')
ax2.barh(df1.index, df1.values, label='Presidi Ospedalieri per Regioni')
ax3.barh(df1.index, df1.values, label='Presidi Ospedalieri per Regioni')

ax4.pie(dfpro['provincia'], labels=dfpro['nome_area'], autopct='%1.0f%%')
ax5.pie(dfpro['provincia'], labels=dfpro['nome_area'], autopct='%1.0f%%')
ax6.pie(dfpro['provincia'], labels=dfpro['nome_area'], autopct='%1.0f%%')
plt.rcParams["figure.figsize"] = (26,6)
plt.show()

# %% [markdown]
# 9. Salvare il grafico in un file .png

# %%
fig.savefig("output.png")
